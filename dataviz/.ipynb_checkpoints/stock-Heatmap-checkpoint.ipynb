# %%
# does not do what i want

import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import pandas as pd
import plotly.graph_objs as go

# Load dataset
df = pd.read_csv('./df_ca2_dataviz.csv')

# Create a Dash web application
app = dash.Dash(__name__)

# Define the layout of the application
app.layout = html.Div(children=[
    html.H1(children='Name Counts Heatmap'),

    # Input for user to enter the name
    dcc.Input(id='name-input', type='text', value='John', placeholder='Enter a name'),

    # Graph component for the heatmap
    dcc.Graph(id='name-heatmap'),

])

# Define the callback to update the heatmap based on the entered name
@app.callback(
    Output('name-heatmap', 'figure'),
    [Input('name-input', 'value')]
)
def update_heatmap(selected_name):
    # Filter the dataset based on the selected name
    filtered_df = df[df['Name'] == selected_name]

    # Create a pivot table for the heatmap
    pivot_df = filtered_df.pivot_table(values='Count', index='Year', columns='State', aggfunc='sum', fill_value=0)

    # Create the heatmap trace
    heatmap_trace = go.Heatmap(
        z=pivot_df.values.tolist(),
        x=pivot_df.columns,
        y=pivot_df.index,
        colorscale='Viridis',
    )

    # Define the layout of the heatmap
    layout = go.Layout(title=f'Name Counts Heatmap for {selected_name}',
                       xaxis=dict(title='State'),
                       yaxis=dict(title='Year'))

    # Create the figure
    figure = {'data': [heatmap_trace], 'layout': layout}

    return figure

# Run the Dash app
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# Address already in use
# Port 8050 is in use by another program. Either identify and stop that program, or start the server with a different port.
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/hduser/.local/lib/python3.10/site-packages/werkzeug/serving.py", line 746, in __init__
#     self.server_bind()
#   File "/usr/lib/python3.10/http/server.py", line 137, in server_bind
#     socketserver.TCPServer.server_bind(self)
#   File "/usr/lib/python3.10/socketserver.py", line 466, in server_bind
#     self.socket.bind(self.server_address)
# OSError: [Errno 98] Address already in use
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_4876/4013112375.py", line 58, in <module>
#     app.run_server(debug=True)
#   File "/home/hduser/.local/lib/python3.10/site-packages/dash/dash.py", line 2175, in run_server
#     self.run(*args, **kwargs)
#   File "/home/hduser/.local/lib/python3.10/site-packages/dash/dash.py", line 2066, in run
#     jupyter_dash.run_app(
#   File "/home/hduser/.local/lib/python3.10/site-packages/dash/_jupyter.py", line 329, in run_app
#     server = make_server(host, port, app.server, threaded=True, processes=0)
#   File "/home/hduser/.local/lib/python3.10/site-packages/werkzeug/serving.py", line 917, in make_server
#     return ThreadedWSGIServer(
#   File "/home/hduser/.local/lib/python3.10/site-packages/werkzeug/serving.py", line 769, in __init__
#     sys.exit(1)
# SystemExit: 1
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/lib/python3/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/lib/python3/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
# AttributeError: 'tuple' object has no attribute 'tb_frame'
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/werkzeug/serving.py in __init__(self, host, port, app, handler, passthrough_errors, ssl_context, fd)
#     745             try:
# --> 746                 self.server_bind()
#     747                 self.server_activate()
#
# /usr/lib/python3.10/http/server.py in server_bind(self)
#     136         """Override server_bind to store the server name."""
# --> 137         socketserver.TCPServer.server_bind(self)
#     138         host, port = self.server_address[:2]
#
# /usr/lib/python3.10/socketserver.py in server_bind(self)
#     465             self.socket.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)
# --> 466         self.socket.bind(self.server_address)
#     467         self.server_address = self.socket.getsockname()
#
# OSError: [Errno 98] Address already in use
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /tmp/ipykernel_4876/4013112375.py in <module>
#      57 if __name__ == '__main__':
# ---> 58     app.run_server(debug=True)
#
# ~/.local/lib/python3.10/site-packages/dash/dash.py in run_server(self, *args, **kwargs)
#    2174         """
# -> 2175         self.run(*args, **kwargs)
#
# ~/.local/lib/python3.10/site-packages/dash/dash.py in run(self, host, port, proxy, debug, jupyter_mode, jupyter_width, jupyter_height, jupyter_server_url, dev_tools_ui, dev_tools_props_check, dev_tools_serve_dev_bundles, dev_tools_hot_reload, dev_tools_hot_reload_interval, dev_tools_hot_reload_watch_interval, dev_tools_hot_reload_max_retry, dev_tools_silence_routes_logging, dev_tools_prune_errors, **flask_run_options)
#    2065         if jupyter_dash.active:
# -> 2066             jupyter_dash.run_app(
#    2067                 self,
#
# ~/.local/lib/python3.10/site-packages/dash/_jupyter.py in run_app(self, app, mode, width, height, host, port, server_url)
#     328
# --> 329         server = make_server(host, port, app.server, threaded=True, processes=0)
#     330         logging.getLogger("werkzeug").setLevel(logging.ERROR)
#
# ~/.local/lib/python3.10/site-packages/werkzeug/serving.py in make_server(host, port, app, threaded, processes, request_handler, passthrough_errors, ssl_context, fd)
#     916     if threaded:
# --> 917         return ThreadedWSGIServer(
#     918             host, port, app, request_handler, passthrough_errors, ssl_context, fd=fd
#
# ~/.local/lib/python3.10/site-packages/werkzeug/serving.py in __init__(self, host, port, app, handler, passthrough_errors, ssl_context, fd)
#     768
# --> 769                 sys.exit(1)
#     770             except BaseException:
#
# SystemExit: 1
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2068                     stb = ['An exception has occurred, use %tb to see '
#    2069                            'the full traceback.\n']
# -> 2070                     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    2071                                                                      value))
#    2072                 else:
#
# /usr/lib/python3/dist-packages/IPython/core/ultratb.py in get_exception_only(self, etype, value)
#     752         value : exception value
#     753         """
# --> 754         return ListTB.structured_traceback(self, etype, value)
#     755
#     756     def show_exception_only(self, etype, evalue):
#
# /usr/lib/python3/dist-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     627             chained_exceptions_tb_offset = 0
#     628             out_list = (
# --> 629                 self.structured_traceback(
#     630                     etype, evalue, (etb, chained_exc_ids),
#     631                     chained_exceptions_tb_offset, context)
#
# /usr/lib/python3/dist-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1365         else:
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#
# /usr/lib/python3/dist-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1265         if mode in self.verbose_modes:
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#
# /usr/lib/python3/dist-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1122         """Return a nice text document describing the traceback."""
#    1123
# -> 1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1125                                                                tb_offset)
#    1126
#
# /usr/lib/python3/dist-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# /usr/lib/python3/dist-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()
